# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
! cp "/content/drive/My Drive/compete/Training Dataset_v3.zip" /content/

# %%
! unzip "/content/Training Dataset_v3.zip" > data_unzip.log
# Out:
# replace train/img0367.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace train/img0367.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace train/img0367.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace train/img0367.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
! cat "/content/train/img0001.txt"
# Out:
# 0,779,276,26,60
# 0,680,261,35,52
# 0,657,348,40,53
# 0,717,275,28,59
# 0,858,255,23,66
# 0,757,349,34,56
# 0,984,262,33,52
# 0,913,284,28,53
# 0,822,259,25,65
# 0,753,275,31,63
# 0,722,345,35,61
# 0,1695,23,66,37
# 0,853,344,37,67
# 0,956,335,32,64
# 0,652,267,30,77
# 0,523,511,29,65
# 0,1020,261,30,59
# 0,577,350,36,51
# 0,945,254,32,61
# 0,491,519,40,53
# 0,552,277,29,59
# 0,990,332,35,60
# 0,1026,740,41,71
# 0,880,264,31,55
# 0,1693,70,59,34
# 0,1021,334,28,59
# 0,488,350,31,67
# 0,758,499,38,52
# 0,786,346,26,56
# 0,515,356,33,77
# 0,684,344,29,58
# 0,444,267,37,66
# 0,893,359,23,51
# 0,1806,757,36,64
# 0,546,349,34,62
# 0,822,356,30,62
# 0,454,506,36,64
# 0,967,741,33,60
# 0,593,499,36,60
# 0,650,503,62,78
# 0,928,509,31,60
# 0,555,513,41,58
# 0,720,513,36,63
# 0,520,265,24,58
# 0,617,345,32,51
# 0,1804,24,35,61
# 0,892,510,48,55
# 0,945,505,40,50
# 0,1683,9,59,33
# 0,529,589,31,66
# 0,1071,732,28,58
# 0,451,350,28,72
# 0,1053,335,37,61
# 0,691,508,42,70
# 0,1025,506,33,56
# 0,863,502,38,67
# 0,790,501,33,76
# 0,999,504,33,65
# 0,1803,675,34,58
# 0,493,585,29,56
# 0,1797,590,38,57
# 0,456,581,27,75
# 0,621,501,38,81
# 0,1071,822,28,55
# 1,1262,337,32,87
# 0,1811,193,36,64
# 0,1804,358,35,57
# 0,1799,515,40,69
# 3,408,160,16,25
# 3,431,162,14,31
# 3,444,163,13,23
# 3,582,158,16,24
# 3,607,163,10,23
# 3,623,165,15,21
# 3,647,156,15,26
# 3,1237,147,13,21
# 3,1269,151,12,23
# 3,1282,145,14,32
# 3,1294,145,8,27

# %%
! rm -rf /content/yolo
! mkdir /content/yolo

# %%
from bs4 import BeautifulSoup
import os
import shutil

image_w = 1920
image_h = 1080

status_dic = {'car': 0, 'hov': 1, 'person': 2, 'motorcycle': 3}
def getYoloFormat(filename, data_path, yolo_path, newname):   
    if(filename[-3:] == 'txt'):
        with open(data_path + filename, 'r') as f:
            ary = []
            for line in f.readlines():
                # print(line)
                line = line.split(',')
                objclass = int(line[0])
                x_min = int(line[1])
                y_min = int(line[2])
                box_w = int(line[3])
                box_h = int(line[4][:-1])
                x = (x_min + (box_w)/2) / image_w
                y = (y_min + (box_h)/2) / image_h
                w = box_w / image_w
                h = box_h / image_h
                ary.append(' '.join([str(objclass), str(x),str(y),str(w),str(h)]))

            if os.path.exists(data_path + filename[:-3] + 'png'):
                shutil.copyfile(data_path + filename[:-3] + 'png', yolo_path + "{:0>4d}".format(int(newname/2)+1) + '.jpg')
# 0 0.8760416666666667 0.011111111111111112 0.010416666666666666 0.020370370370370372
# 0 0.87109375 0.03657407407407407 0.011979166666666667 0.026851851851851852
# 0 0.8619791666666666 0.044444444444444446 0.011458333333333333 0.020370370370370372
# 0 0.884375 0.03518518518518519 0.011458333333333333 0.027777777777777776
# 0 0.8934895833333333 0.03657407407407407 0.009895833333333333 0.030555555555555555
# 0 0.88984375 0.011574074074074073 0.009895833333333333 0.023148148148148147
# 0 0.8984375 0.011111111111111112 0.011458333333333333 0.018518518518518517
# 0 0.9114583333333334 0.012962962962962963 0.010416666666666666 0.024074074074074074
# 0 0.9098958333333333 0.03888888888888889 0.010416666666666666 0.022222222222222223
# 0 0.91796875 0.043055555555555555 0.011979166666666667 0.025
# 0 0.9213541666666667 0.010648148148148148 0.0125 0.019444444444444445
# 0 0.9354166666666667 0.011574074074074073 0.009375 0.021296296296296296
# 0 0.946875 0.0125 0.009375 0.023148148148148147
# 0 0.9552083333333333 0.013888888888888888 0.010416666666666666 0.024074074074074074
# 0 0.9520833333333333 0.03564814814814815 0.013541666666666667 0.023148148148148147
# 0 0.9658854166666667 0.0375 0.0140625 0.025
# 0 0.97109375 0.012037037037037037 0.0140625 0.024074074074074074
# 0 0.9796875 0.011574074074074073 0.009375 0.021296296296296296
# 0 0.9903645833333333 0.03518518518518519 0.015104166666666667 0.02962962962962963
# 0 0.5734375 0.5939814814814814 0.023958333333333335 0.021296296296296296
# 3 0.7052083333333333 0.10324074074074074 0.004166666666666667 0.01574074074074074
# 3 0.7078125 0.1050925925925926 0.003125 0.017592592592592594
# 3 0.7125 0.09814814814814815 0.004166666666666667 0.016666666666666666
# 3 0.72265625 0.10231481481481482 0.005729166666666666 0.017592592592592594
# 1 0.7010416666666667 0.011574074074074073 0.010416666666666666 0.021296296296296296

# %%
from PIL import Image
Image.open('/content/yolo/1000.jpg')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
! rm -rf /content/cfg_mask
! mkdir /content/cfg_mask

# %%
datasets = ['/content/yolo/'+ f for f in os.listdir('/content/yolo/') if not f.endswith('.txt')]
len(datasets) * 0.8
# Out:
# 800.0

# %%
with open('/content/cfg_mask/train.txt', 'w') as f:
    f.write('\n'.join(datasets[0:540]))

# %%
with open('/content/cfg_mask/test.txt', 'w') as f:
    f.write('\n'.join(datasets[540:]))

# %%
with open('/content/train/img0001.txt', 'r') as f:
    for  i in f.readlines():
        print(i)
     # data = f.readlines()
# print(data)
# Out:
# 0,779,276,26,60
#
# 0,680,261,35,52
#
# 0,657,348,40,53
#
# 0,717,275,28,59
#
# 0,858,255,23,66
#
# 0,757,349,34,56
#
# 0,984,262,33,52
#
# 0,913,284,28,53
#
# 0,822,259,25,65
#
# 0,753,275,31,63
#
# 0,722,345,35,61
#
# 0,1695,23,66,37
#
# 0,853,344,37,67
#
# 0,956,335,32,64
#
# 0,652,267,30,77
#
# 0,523,511,29,65
#
# 0,1020,261,30,59
#
# 0,577,350,36,51
#
# 0,945,254,32,61
#
# 0,491,519,40,53
#
# 0,552,277,29,59
#
# 0,990,332,35,60
#
# 0,1026,740,41,71
#
# 0,880,264,31,55
#
# 0,1693,70,59,34
#
# 0,1021,334,28,59
#
# 0,488,350,31,67
#
# 0,758,499,38,52
#
# 0,786,346,26,56
#
# 0,515,356,33,77
#
# 0,684,344,29,58
#
# 0,444,267,37,66
#
# 0,893,359,23,51
#
# 0,1806,757,36,64
#
# 0,546,349,34,62
#
# 0,822,356,30,62
#
# 0,454,506,36,64
#
# 0,967,741,33,60
#
# 0,593,499,36,60
#
# 0,650,503,62,78
#
# 0,928,509,31,60
#
# 0,555,513,41,58
#
# 0,720,513,36,63
#
# 0,520,265,24,58
#
# 0,617,345,32,51
#
# 0,1804,24,35,61
#
# 0,892,510,48,55
#
# 0,945,505,40,50
#
# 0,1683,9,59,33
#
# 0,529,589,31,66
#
# 0,1071,732,28,58
#
# 0,451,350,28,72
#
# 0,1053,335,37,61
#
# 0,691,508,42,70
#
# 0,1025,506,33,56
#
# 0,863,502,38,67
#
# 0,790,501,33,76
#
# 0,999,504,33,65
#
# 0,1803,675,34,58
#
# 0,493,585,29,56
#
# 0,1797,590,38,57
#
# 0,456,581,27,75
#
# 0,621,501,38,81
#
# 0,1071,822,28,55
#
# 1,1262,337,32,87
#
# 0,1811,193,36,64
#
# 0,1804,358,35,57
#
# 0,1799,515,40,69
#
# 3,408,160,16,25
#
# 3,431,162,14,31
#
# 3,444,163,13,23
#
# 3,582,158,16,24
#
# 3,607,163,10,23
#
# 3,623,165,15,21
#
# 3,647,156,15,26
#
# 3,1237,147,13,21
#
# 3,1269,151,12,23
#
# 3,1282,145,14,32
#
# 3,1294,145,8,27

# %%
print(os.listdir('/content/train'))
print(sorted(os.listdir('/content/train'), key=str.lower))
# Out:
# ['img0001.png', 'img0001.txt', 'img0002.png', 'img0002.txt', 'img0003.png', 'img0003.txt', 'img0004.png', 'img0004.txt', 'img0005.png', 'img0005.txt', 'img0006.png', 'img0006.txt', 'img0007.png', 'img0007.txt', 'img0008.png', 'img0008.txt', 'img0009.png', 'img0009.txt', 'img0010.png', 'img0010.txt', 'img0011.png', 'img0011.txt', 'img0012.png', 'img0012.txt', 'img0013.png', 'img0013.txt', 'img0014.png', 'img0014.txt', 'img0015.png', 'img0015.txt', 'img0016.png', 'img0016.txt', 'img0017.png', 'img0017.txt', 'img0018.png', 'img0018.txt', 'img0019.png', 'img0019.txt', 'img0020.png', 'img0020.txt', 'img0021.png', 'img0021.txt', 'img0022.png', 'img0022.txt', 'img0023.png', 'img0023.txt', 'img0024.png', 'img0024.txt', 'img0025.png', 'img0025.txt', 'img0026.png', 'img0026.txt', 'img0027.png', 'img0027.txt', 'img0028.png', 'img0028.txt', 'img0029.png', 'img0029.txt', 'img0030.png', 'img0030.txt', 'img0031.png', 'img0031.txt', 'img0032.png', 'img0032.txt', 'img0033.png', 'img0033.txt', 'img0034.png', 'img0034.txt', 'img0035.png', 'img0035.txt', 'img0036.png', 'img0036.txt', 'img0037.png', 'img0037.txt', 'img0038.png', 'img0038.txt', 'img0039.png', 'img0039.txt', 'img0040.png', 'img0040.txt', 'img0041.png', 'img0041.txt', 'img0042.png', 'img0042.txt', 'img0043.png', 'img0043.txt', 'img0044.png', 'img0044.txt', 'img0045.png', 'img0045.txt', 'img0046.png', 'img0046.txt', 'img0047.png', 'img0047.txt', 'img0048.png', 'img0048.txt', 'img0049.png', 'img0049.txt', 'img0050.png', 'img0050.txt', 'img0051.png', 'img0051.txt', 'img0052.png', 'img0052.txt', 'img0053.png', 'img0053.txt', 'img0054.png', 'img0054.txt', 'img0055.png', 'img0055.txt', 'img0056.png', 'img0056.txt', 'img0057.png', 'img0057.txt', 'img0058.png', 'img0058.txt', 'img0059.png', 'img0059.txt', 'img0060.png', 'img0060.txt', 'img0061.png', 'img0061.txt', 'img0062.png', 'img0062.txt', 'img0063.png', 'img0063.txt', 'img0064.png', 'img0064.txt', 'img0065.png', 'img0065.txt', 'img0066.png', 'img0066.txt', 'img0067.png', 'img0067.txt', 'img0068.png', 'img0068.txt', 'img0069.png', 'img0069.txt', 'img0070.png', 'img0070.txt', 'img0071.png', 'img0071.txt', 'img0072.png', 'img0072.txt', 'img0073.png', 'img0073.txt', 'img0074.png', 'img0074.txt', 'img0075.png', 'img0075.txt', 'img0076.png', 'img0076.txt', 'img0077.png', 'img0077.txt', 'img0078.png', 'img0078.txt', 'img0079.png', 'img0079.txt', 'img0080.png', 'img0080.txt', 'img0081.png', 'img0081.txt', 'img0082.png', 'img0082.txt', 'img0083.png', 'img0083.txt', 'img0084.png', 'img0084.txt', 'img0085.png', 'img0085.txt', 'img0086.png', 'img0086.txt', 'img0087.png', 'img0087.txt', 'img0088.png', 'img0088.txt', 'img0089.png', 'img0089.txt', 'img0090.png', 'img0090.txt', 'img0091.png', 'img0091.txt', 'img0092.png', 'img0092.txt', 'img0093.png', 'img0093.txt', 'img0094.png', 'img0094.txt', 'img0095.png', 'img0095.txt', 'img0096.png', 'img0096.txt', 'img0097.png', 'img0097.txt', 'img0098.png', 'img0098.txt', 'img0099.png', 'img0099.txt', 'img0100.png', 'img0100.txt', 'img0101.png', 'img0101.txt', 'img0102.png', 'img0102.txt', 'img0103.png', 'img0103.txt', 'img0104.png', 'img0104.txt', 'img0105.png', 'img0105.txt', 'img0106.png', 'img0106.txt', 'img0107.png', 'img0107.txt', 'img0108.png', 'img0108.txt', 'img0109.png', 'img0109.txt', 'img0110.png', 'img0110.txt', 'img0111.png', 'img0111.txt', 'img0112.png', 'img0112.txt', 'img0113.png', 'img0113.txt', 'img0114.png', 'img0114.txt', 'img0115.png', 'img0115.txt', 'img0116.png', 'img0116.txt', 'img0117.png', 'img0117.txt', 'img0118.png', 'img0118.txt', 'img0119.png', 'img0119.txt', 'img0120.png', 'img0120.txt', 'img0121.png', 'img0121.txt', 'img0122.png', 'img0122.txt', 'img0123.png', 'img0123.txt', 'img0124.png', 'img0124.txt', 'img0125.png', 'img0125.txt', 'img0126.png', 'img0126.txt', 'img0127.png', 'img0127.txt', 'img0128.png', 'img0128.txt', 'img0129.png', 'img0129.txt', 'img0130.png', 'img0130.txt', 'img0131.png', 'img0131.txt', 'img0132.png', 'img0132.txt', 'img0133.png', 'img0133.txt', 'img0134. ...

# %%
a = ['12', '23', '34']
for i in a:
    print(i)
# Out:
# 12
# 23
# 34

# %%
print(type("{:0>4d}".format(1)))
# Out:
# <class 'str'>
